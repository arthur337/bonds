# %%
library(tidyverse)
library(lubridate)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 2.2.1     ✔ purrr   0.2.4
# ✔ tibble  1.4.1     ✔ dplyr   0.7.4
# ✔ tidyr   0.7.2     ✔ stringr 1.3.1
# ✔ readr   1.1.1     ✔ forcats 0.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘lubridate’
#
# The following object is masked from ‘package:base’:
#
#     date

# %%
a <- read_csv("BONDS.csv")
# Out:
# Parsed with column specification:
# cols(
#   Name = col_character(),
#   Ticker = col_character(),
#   Coupon = col_double(),
#   `Issued Amount` = col_double(),
#   Maturity = col_character(),
#   Currency = col_character(),
#   Identifier = col_character(),
#   `Bloomberg Composite Rating` = col_character(),
#   `Ask Price` = col_character(),
#   `Ask Yield to Maturity` = col_character(),
#   Source = col_character()
# )

# %%
b <- a %>% mutate(Size_Mio=parse_double(`Issued Amount`)/1000000, 
                  Maturity = parse_date(Maturity, "%d/%m/%Y")) %>% 
    select(Name,Ticker,Size_Mio,Maturity,Yield=`Ask Yield to Maturity`,Identifier) %>% 
    mutate(Yield = as.numeric(Yield),Year = year(Maturity)) %>% distinct()
# Out:
# Warning message in evalq(as.numeric(Yield), <environment>):
# “NAs introduced by coercion”

# %%
c <- b %>% filter(Ticker %in% c("MGS", "MGII"))

# %%
chart1 <- c %>% ggplot(aes(Maturity,Yield,color=Ticker)) +
    geom_point(aes(size=Size_Mio), alpha=0.5) +
    geom_rug() +
    stat_smooth(geom='line', alpha=0.5, se=FALSE) +
    scale_x_date(date_breaks = "4 year", date_labels = "%Y") + 
    scale_y_continuous(breaks=round(seq(min(c$Yield),max(c$Yield),by=0.2),1)) + 
    labs(title = "Malaysian Govies Bonds",
        subtitle = "Maturities vs Yield",
        caption = "Source: Bloomberg") + 
    theme_bw() +
    theme(legend.position = c(0.9, 0.4))

# %%
chart2 <- c %>% ggplot(aes(Year,Size_Mio)) +
    geom_bar(stat="identity", aes(fill=Ticker), colour="black") +
    labs(y="Issuance size (Mio MYR)",
        title = "Malaysian Govies Bonds",
        subtitle = "Size of Maturities by Year",
        caption = "Source: Bloomberg") + 
    theme_bw() +
    theme(axis.text.x  = element_text(angle=90)) +
    scale_x_continuous(breaks = pretty(c$Year, n = 20)) +
    theme(legend.position = c(0.92, 0.8))

# %%
options(repr.plot.width=10, repr.plot.height=5)
chart1
chart2
# Out:
# `geom_smooth()` using method = 'loess'

# %%
write_excel_csv(c,"Bond_Data.csv")

# %%
chart1
ggsave("bond1.pdf", width = 25, height = 20, units = "cm")
chart2
ggsave("bond2.pdf", width = 25, height = 20, units = "cm")
# Out:
# `geom_smooth()` using method = 'loess'
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “span too small.   fewer data values than degrees of freedom.”Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at 20160”Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 123.92”Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  0”Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “There are other near singularities as well. 3959.6”
# `geom_smooth()` using method = 'loess'
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “span too small.   fewer data values than degrees of freedom.”Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at 20160”Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 123.92”Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  0”Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “There are other near singularities as well. 3959.6”

# %%
chart3 <- c %>% ggplot(aes(Maturity,Size_Mio,fill=Ticker)) +
    geom_freqpoly(mapping = aes(colour = Ticker), binwidth = 5000000) +
    labs(y="Issuance size (Mio MYR)",
        title = "Malaysian Govies Bonds",
        subtitle = "Size of Maturities by Year",
        caption = "Source: Bloomberg") + 
    theme_bw() +
    theme(axis.text.x  = element_text(angle=90)) +
    theme(legend.position = c(0.92, 0.8)) 

chart2
